# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# mpg = sns.load_dataset('mpg')

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
plt.figure(figsize = (12,5))
plt.plot(x, y, 'r')
plt.xlabel('This is X', fontsize =10)
plt.xticks([1,2,3,4,5], ['Bart', 'Lisa', 'Jack', 'Andi', 'As'])
plt.ylabel('This is Y', fontsize = 10)
plt.yticks([1,2,3,4,5])
plt.title('This is title')
# plt.show()
# Out:
# Text(0.5, 1.0, 'This is title')

# %%
plt.plot(x, y, 'r--')
plt.plot(y, x, 'g*')

# %%
plt.figure(figsize = (12,8))

plt.subplot(2,2,1)
plt.plot(x, y, 'r--')
plt.title('Ini subplot 1')
plt.axis('off')

plt.subplot(2,2,2)
plt.plot(y, x, 'g*')
plt.title('Ini subplot 2')

plt.subplot(2,2,3)
plt.plot(x,y)

# %%
fig = plt.figure(facecolor = 'yellow')

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3])

axes1.plot(x, y, 'b')
axes1.set_xlabel('Ini X1')
axes1.set_ylabel('Ini Y1')
axes1.set_title('Ini Title 1')

axes2.plot(y, x, 'r')
# axes2.set_xlabel('Ini X2')
# axes2.set_ylabel('Ini Y2')
# axes2.set_title('Ini Title 2')
axes2.set_axis_off()

# %%
fig, axes = plt.subplots(nrows = 2, ncols =2, figsize = (8,8), facecolor = 'yellow')
# for ax in axes:
#     ax.plot(x, y, 'b')
#     ax.set_xlabel('Ini X')
#     ax.set_ylabel('Ini Y')
#     ax.set_title('Ini Title')
# axes
axes[0][0].plot(x,y,'b', label = 'Ini 1')
axes[0][0].plot(y,x,'--r', label = 'Ini 2')
axes[0][0].legend()
plt.tight_layout()

# %% [markdown]
# ##  Latihan PR

# %%
from yahoo_historical import Fetcher

# %%
dfINDF = Fetcher('INDF.JK', [2011, 1, 1], [2019, 12, 20]).getHistorical()

# %%
dfINDF.head()
# Out:
#          Date    Open    High     Low   Close    Adj Close      Volume
# 0  2011-01-03  4950.0  4950.0  4825.0  4950.0  3838.854492  14112500.0
# 1  2011-01-04  5100.0  5100.0  4925.0  5100.0  3955.183105  27676500.0
# 2  2011-01-05  4950.0  5100.0  4950.0  4950.0  3838.854492  11431000.0
# 3  2011-01-06  4850.0  4950.0  4825.0  4850.0  3761.302002  14167000.0
# 4  2011-01-07  4725.0  4875.0  4700.0  4725.0  3664.361328  16699000.0

# %%
dfINDF.isna().any()
# Out:
# Date         False
# Open          True
# High          True
# Low           True
# Close         True
# Adj Close     True
# Volume        True
# dtype: bool

# %%
dfINDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2241 entries, 0 to 2240
# Data columns (total 7 columns):
# Date         2241 non-null object
# Open         2232 non-null float64
# High         2232 non-null float64
# Low          2232 non-null float64
# Close        2232 non-null float64
# Adj Close    2232 non-null float64
# Volume       2232 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 122.7+ KB

# %%
dfINDF = dfINDF.fillna(method = 'ffill')

# %%
dfINDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2241 entries, 0 to 2240
# Data columns (total 7 columns):
# Date         2241 non-null object
# Open         2241 non-null float64
# High         2241 non-null float64
# Low          2241 non-null float64
# Close        2241 non-null float64
# Adj Close    2241 non-null float64
# Volume       2241 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 122.7+ KB

# %%
dfINDF['Date'] = pd.to_datetime(dfINDF['Date'] )

# %%
dfINDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2241 entries, 0 to 2240
# Data columns (total 7 columns):
# Date         2241 non-null datetime64[ns]
# Open         2241 non-null float64
# High         2241 non-null float64
# Low          2241 non-null float64
# Close        2241 non-null float64
# Adj Close    2241 non-null float64
# Volume       2241 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 122.7 KB

# %%
dfINDF.set_index('Date', inplace = True)

# %%
dfINDF
# Out:
#               Open    High     Low   Close    Adj Close      Volume
# Date
# 2011-01-03  4950.0  4950.0  4825.0  4950.0  3838.854492  14112500.0
# 2011-01-04  5100.0  5100.0  4925.0  5100.0  3955.183105  27676500.0
# 2011-01-05  4950.0  5100.0  4950.0  4950.0  3838.854492  11431000.0
# 2011-01-06  4850.0  4950.0  4825.0  4850.0  3761.302002  14167000.0
# 2011-01-07  4725.0  4875.0  4700.0  4725.0  3664.361328  16699000.0
# ...            ...     ...     ...     ...          ...         ...
# 2019-12-16  7750.0  7875.0  7750.0  7875.0  7875.000000   4859200.0
# 2019-12-17  7900.0  7950.0  7850.0  7950.0  7950.000000   6208100.0
# 2019-12-18  7975.0  7975.0  7900.0  7950.0  7950.000000   8303900.0
# 2019-12-19  7950.0  7950.0  7800.0  7925.0  7925.000000   4551700.0
# 2019-12-20  7850.0  7925.0  7800.0  7925.0  7925.000000  10539600.0
#
# [2241 rows x 6 columns]

# %%
plt.figure(figsize = (8,8))
plt.plot(dfINDF['Close'])
# Out:
# C:\Users\MSI\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
